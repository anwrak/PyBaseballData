# %%
import pandas as pd

class game:
    def __init__(self, id):
        self.id = id
        

file = open('../../baseball data/event/2022eve/2022ARI.EVN', 'r')

for aline in file:
    print(aline)
# Out:
# id,ARI202204070
#
# version,2
#
# info,visteam,SDN
#
# info,hometeam,ARI
#
# info,site,PHO01
#
# info,date,2022/04/07
#
# info,number,0
#
# info,starttime,6:40PM
#
# info,daynight,night
#
# info,innings,9
#
# info,tiebreaker,2
#
# info,usedh,true
#
# info,umphome,vanol901
#
# info,ump1b,belld901
#
# info,ump2b,barbs901
#
# info,ump3b,valej901
#
# info,umplf,(none)
#
# info,umprf,(none)
#
# info,inputtime,2022/09/26 06:24:00
#
# info,howscored,unknown
#
# info,pitches,pitches
#
# info,oscorer,black701
#
# info,temp,93
#
# info,winddir,ltor
#
# info,windspeed,6
#
# info,fieldcond,unknown
#
# info,precip,none
#
# info,sky,sunny
#
# info,timeofgame,198
#
# info,attendance,35508
#
# info,wp,mantj002
#
# info,lp,suarr002
#
# info,save,
#
# start,nolaa002,"Austin Nola",0,1,2
#
# start,machm001,"Manny Machado",0,2,5
#
# start,cronj001,"Jake Cronenworth",0,3,4
#
# start,voitl001,"Luke Voit",0,4,10
#
# start,myerw001,"Wil Myers",0,5,9
#
# start,hosme001,"Eric Hosmer",0,6,3
#
# ...
